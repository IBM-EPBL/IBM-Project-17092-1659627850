# %%
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import numpy as nps

# %%
model=load_model(r'fruitdata.h5')

# %%
img=image.load_img(r'C:\Users\Praveen\Downloads\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\fruit-dataset\fruit-dataset\test\Peach___healthy\04c2f170-d421-473e-9131-c4aaa681a9d2___Rutg._HL 3724.jpg',grayscale=False,target_size=(128,128))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
x=image.img_to_array(img)
x=nps.expand_dims(x,axis=0)

# %%
pred=(model.predict(x) > 0.5).astype("int32")
# Out:
# 1/1 [==============================] - 0s 335ms/step

# %%
pred
# Out:
# array([[0, 0, 0, 1, 0, 0]])
