# %%
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import numpy as nps

# %%
model=load_model(r'C:\Users\Praveen\Praveen\vegetabledata.h5')

# %%
img=image.load_img(r'C:\Users\Praveen\Downloads\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\Veg-dataset\Veg-dataset\test_set\Potato___healthy\c85bacb0-e5e8-4127-a0b0-a7342f2cab5f___RS_HL 5406.jpg',grayscale=False,target_size=(128,128))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
x=image.img_to_array(img)
x=nps.expand_dims(x,axis=0)

# %%
pred=(model.predict(x) > 0.5).astype("int32")
# Out:
# 1/1 [==============================] - 0s 269ms/step

# %%
pred
# Out:
# array([[0, 0, 0, 0, 0, 0, 0, 0, 1]])
