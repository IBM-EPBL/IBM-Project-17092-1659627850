# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread

# %%
I = imread(r'C:\Users\USER\Desktop\Fruit-Dataset\test\Peach___healthy\Apple___healthy(1)\Apple1.JPG')
J = imread(r'C:\Users\USER\Desktop\Fruit-Dataset\test\Peach___healthy\Apple___healthy(1)\Apple2.JPG')

# %%
plt.figure()
plt.subplot(121), plt.imshow(I)
plt.subplot(122), plt.imshow(J)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(np.abs(I[:, :, 0].astype(float) - J[:, :, 0].astype(float)), cmap='gray')
plt.show()

# %%
d = imread(r'C:\Users\USER\Desktop\Fruit-Dataset\test\Peach___healthy\Apple___healthy(1)\8a5fd341-9f0f-4c54-8f9d-b9c4c5b16994___RS_HL 7650.JPG')
mask = imread(r'C:\Users\USER\Desktop\Fruit-Dataset\test\Peach___healthy\Apple___healthy(1)\7bf0ddc7-fa85-442b-859b-486b087a4641___RS_HL 5837.JPG')

print(np.amin(d), np.amax(d))
print(np.amin(mask), np.amax(mask))
# Out:
# 7 235
# 0 245

# %%
plt.figure(), plt.imshow(mask), plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  None)

# %%
mask = mask[:, :, 0]

# %%
maskInv = np.zeros_like(mask)
maskInv[mask == 0] = 255
maskInv[mask == 255] = 0
plt.figure(), plt.imshow(maskInv, cmap='gray'), plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  None)
