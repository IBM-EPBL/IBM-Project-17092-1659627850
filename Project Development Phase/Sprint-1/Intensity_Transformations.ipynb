# %% [markdown]
# # Image Arithmetics

# %% [markdown]
# You can do some meaningful arithmetics on images to get various results. For example you can add images, subtract them, or even multiply them.
#
# Now, we are going to test some of these mathematical operations.

# %%
import imageio as iio
from skimage.io import imread
import matplotlib.pyplot as plt
import numpy as np

# %%
live = iio.imread(r'C:\Users\USER\Desktop\Fruit-Dataset\test\Peach___healthy\Apple___Black_rot(1)\leaf.JPG')
mask = iio.imread(r'C:\Users\USER\Desktop\Fruit-Dataset\test\Peach___healthy\Apple___Black_rot(1)\leaf2.JPG')

plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(live, cmap='gray')
plt.subplot(122), plt.imshow(mask, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(live, cmap='gray')
plt.subplot(122), plt.imshow(live - 20, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.subplot(131), plt.imshow(mask - live, cmap='gray')
plt.subplot(132), plt.imshow(-(mask - live + 128), cmap='gray')
plt.subplot(133), plt.imshow(mask - live + 128, cmap='gray')
plt.show()

# %%
shaded = iio.imread(r'C:\Users\USER\Desktop\Fruit-Dataset\test\Peach___healthy\Apple___Black_rot(1)\leaf.JPG')
shading = iio.imread(r'C:\Users\USER\Desktop\Fruit-Dataset\test\Peach___healthy\Apple___Black_rot(1)\leaf2.JPG')

plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(shaded, cmap='gray')
plt.subplot(122), plt.imshow(shading, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(np.multiply(shaded, 1/shading), cmap='gray')
plt.subplot(122), plt.imshow(shaded, cmap='gray')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_30680\1289966496.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   plt.subplot(121), plt.imshow(np.multiply(shaded, 1/shading), cmap='gray')
# C:\Users\USER\AppData\Local\Temp\ipykernel_30680\1289966496.py:2: RuntimeWarning: invalid value encountered in multiply
#   plt.subplot(121), plt.imshow(np.multiply(shaded, 1/shading), cmap='gray')
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Test on the X-ray dental image
xray = iio.imread(r'C:\Users\USER\Desktop\Fruit-Dataset\test\Peach___healthy\Apple___Black_rot(1)\leaf3.JPG')
mask_xray = iio.imread(r'C:\Users\USER\Desktop\Fruit-Dataset\test\Peach___healthy\Peach___Bacterial_spot(1)\peach.JPG')

# %%
plt.figure(figsize=(10, 10))
plt.subplot(121), plt.imshow(xray, cmap='gray')
plt.subplot(122), plt.imshow(mask_xray, cmap='gray')
plt.show()

# %%
plt.figure()
plt.imshow(np.multiply(xray, mask_xray/255), cmap='gray')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Test on another image
scan = iio.imread(r'C:\Users\USER\Desktop\Fruit-Dataset\test\Peach___healthy\Corn_(maize)___Northern_Leaf_Blight(1)\corn.jpg')
print(scan.shape)
# Out:
# (256, 256, 3)

# %%
# Showing the body scan image
plt.figure(figsize=(7, 7))
plt.imshow(scan, cmap='gray')
plt.show()

# %% [markdown]
# # Pixel relationships

# %% [markdown]
# ![sample.gif](attachment:sample.gif)

# %% [markdown]
# # Usual processes in DIP

# %% [markdown]
# # Pixel (Point) processing

# %% [markdown]
# Only individual pixels are entered into a process. The output is dependent on the single pixel values.
#
# Some of this kind of processes are:

# %% [markdown]
# # Histogram Processing

# %% [markdown]
# 1. Contrast Enhancement
# 2. Histogram Equalization
# 3. Histogram Matching
# 4. Histogram Strtching

# %% [markdown]
# # Intensity Transformations

# %% [markdown]
# 1. Negative of an image
# 2. Log transformation
# 3. n-th power transformation
# 4. piecewise transformations

# %% [markdown]
# # Region (Neighborhood) processing

# %% [markdown]
# A region (area) of pixels are entered into a process. The output is dependent on the values of entire region.
#
# A common example of this kind of process includes Spatial Filtering and Morphological Operators, which are:

# %% [markdown]
# 1. Average filtering
# 2. Median filtering
# 3. Sharpening filters
# 4. Edge detectors
# 5. Morphological Operations

# %% [markdown]
# # Histogram of an image

# %% [markdown]
# ![sampl1.gif](attachment:sampl1.gif)

# %% [markdown]
# ![sample2.jfif](attachment:sample2.jfif)#

# %% [markdown]
# ![sample3.jfif](attachment:sample3.jfif)

# %% [markdown]
# ![sample4.jfif](attachment:sample4.jfif)

# %%
plt.figure(figsize=(10, 10))
plt.subplot(211), plt.imshow(xray, cmap='gray')
plt.subplot(212), plt.plot(np.histogram(xray, bins=256)[0])
plt.show()
